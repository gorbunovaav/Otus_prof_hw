# %%
Чтение файла и просмотр первых строк

# %%
import pandas as pd

df = pd.read_csv("churn-bigml-20.csv")
print(df.head())
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
Размерность таблицы

# %%
print(df.shape)
# Out:
# (667, 20)

# %%
Названия столбцов

# %%
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
Общая информация: типы данных, количество ненулевых значений

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
Статистика по числовым столбцам

# %%
print(df.describe())
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# count      667.000000  667.000000             667.000000         667.000000
# mean       102.841079  436.157421               8.407796         180.948126
# std         40.819480   41.783305              13.994480          55.508628
# min          1.000000  408.000000               0.000000          25.900000
# 25%         76.000000  408.000000               0.000000         146.250000
# 50%        102.000000  415.000000               0.000000         178.300000
# 75%        128.000000  415.000000              20.000000         220.700000
# max        232.000000  510.000000              51.000000         334.300000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count       667.000000        667.000000         667.000000       667.000000
# mean        100.937031         30.761769         203.355322       100.476762
# ...

# %%
Проверка пропущенных значений

# %%
print(df.isnull().sum())
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
Распределение целевой переменной (Churn) (клиенты, которые ушли и остались)
# Out:
#   Cell In[4], line 1
#     Распределение целевой переменной (Churn)
#                   ^
# SyntaxError: invalid syntax

# %%
print(df['Churn'].value_counts(normalize=True))
# Out:
# Churn
# False    0.857571
# True     0.142429
# Name: proportion, dtype: float64

# %%
Проверка списка категориальных столбцов

# %%
categorical = df.select_dtypes(include='object').columns
print(categorical)
# Out:
# Index(['State', 'International plan', 'Voice mail plan'], dtype='object')

# %%
Проверка списка числовых столбцов

# %%
numerical = df.select_dtypes(include='number').columns
print(numerical)
# Out:
# Index(['Account length', 'Area code', 'Number vmail messages',
#        'Total day minutes', 'Total day calls', 'Total day charge',
#        'Total eve minutes', 'Total eve calls', 'Total eve charge',
#        'Total night minutes', 'Total night calls', 'Total night charge',
#        'Total intl minutes', 'Total intl calls', 'Total intl charge',
#        'Customer service calls'],
#       dtype='object')

# %%
Визуализация (распределение количества дневных минут звонков (Total day minutes) у клиентов,
которые ушли (Churn == True) и остались (Churn == False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("churn-bigml-20.csv")
sns.boxplot(x='Churn', y='Total day minutes', data=df)
plt.show()

# %%
Убира

# %%
Строим тепловую карту карреляций

# %%
numeric_df = df.select_dtypes(include='number')
print(numeric_df.isnull().sum())     # NaN
print((numeric_df == float('inf')).sum())
print((numeric_df == float('-inf')).sum())
numeric_df = numeric_df.replace([float('inf'), float('-inf')], pd.NA).dropna()

sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# Account length            0
# Area code                 0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# dtype: int64
# Account length            0
# Area code                 0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# dtype: int64
# ...
